# %% [markdown]
# # 02 — Tabular Baselines (E1/E2/E3)
# Linear Regression, Random Forest and XGBoost on (E1) the original 5-feature set, (E2) full raw tabular features, and (E3) engineered features. Identical 80/20 split.

# %%
# Utilities to add the project root to sys.path so `import src` works from notebooks.
import sys, os
from pathlib import Path
ROOT = Path(os.getcwd()).resolve()
while 'src' not in [p.name for p in ROOT.iterdir()] and ROOT.parent != ROOT:
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
import pandas as pd
from src.config import REPORTS_DIR
res = pd.read_csv(REPORTS_DIR / 'results_tabular.csv')
res.pivot(index='experiment', columns='model', values='rmse').round(0)

# %%
res.pivot(index='experiment', columns='model', values='r2').round(4)

# %% [markdown]
# ### Takeaway
# Full/engineered features beat the original 5-feature baseline by a wide margin. XGBoost on engineered features is the strongest untuned tabular model.
